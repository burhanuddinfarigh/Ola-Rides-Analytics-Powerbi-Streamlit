# %%
import sqlite3
import pandas as pd

# %%
df = pd.read_csv("ola_rides_cleaned.csv")

# %%
df.head()
# Out:
#       booking_id booking_status customer_id vehicle_type pickup_location  \
# 0  CNR2940424040      Completed   CID225428         Bike     Magadi Road
# 1  CNR2982357879      Completed   CID270156    Prime Suv   Sahakar Nagar
# 2  CNR1797421769      Completed   CID939555         Mini     Rajajinagar
# 3  CNR8787177882      Completed   CID802429         Mini        Kadugodi
# 4  CNR3612067560      Completed   CID476071         Bike     Tumkur Road
#
#   drop_location  v_tat  c_tat  booking_value payment_method  ride_distance  \
# 0       Varthur  203.0   30.0            158           CASH             13
# 1       Varthur  238.0  130.0            386            UPI             40
# 2   Chamarajpet  252.0   80.0            822    CREDIT CARD             45
# 3   Vijayanagar  231.0   90.0            173            UPI             41
# 4    Whitefield  133.0   40.0            140           CASH             49
#
#    driver_ratings  customer_rating  \
# 0             4.1              4.0
# 1             4.2              4.8
# 2             4.0              3.0
# 3             3.4              4.6
# 4             3.2              4.5
#
#                                       vehicle_images  ride_day  ride_month  \
# 0  https://cdn-icons-png.flaticon.com/128/9983/99...  Thursday           7
# 1  https://cdn-icons-png.flaticon.com/128/9983/99...   Tuesday           7
# 2  https://cdn-icons-png.flaticon.com/128/3202/32...   Tuesday           7
# 3  https://cdn-icons-png.flaticon.com/128/3202/32...  Saturday           7
# 4  https://cdn-icons-png.flaticon.com/128/9983/99...   Tuesday           7
#
#    ride_hour  cancelled_by     booking_datetime  completed_flag
# 0         22           NaN  2024-07-25 22:20:00               1
# 1         19           NaN  2024-07-30 19:59:00               1
# 2          9           NaN  2024-07-02 09:02:00               1
# 3          4           NaN  2024-07-13 04:42:00               1
# 4          9           NaN  2024-07-23 09:51:00               1

# %%
# MEMORY IN DATABASE

# %%
conn = sqlite3.connect(":memory:")

# %%
# DATAFRAME INTO SQL TABLE

# %%
df.to_sql("ola_rides", conn, index=False, if_exists="replace")
print(" SQL environment ready. Table name: ola_rides")
# Out:
#  SQL environment ready. Table name: ola_rides

# %%
#Q1. Retrieve all successful bookings

# %%
query1="""SELECT *
FROM ola_rides
WHERE booking_status = 'Completed';"""

# %%
df_q1 = pd.read_sql_query(query1, conn)
df_q1.head()
# Out:
#       booking_id booking_status customer_id vehicle_type pickup_location  \
# 0  CNR2940424040      Completed   CID225428         Bike     Magadi Road
# 1  CNR2982357879      Completed   CID270156    Prime Suv   Sahakar Nagar
# 2  CNR1797421769      Completed   CID939555         Mini     Rajajinagar
# 3  CNR8787177882      Completed   CID802429         Mini        Kadugodi
# 4  CNR3612067560      Completed   CID476071         Bike     Tumkur Road
#
#   drop_location  v_tat  c_tat  booking_value payment_method  ride_distance  \
# 0       Varthur  203.0   30.0            158           CASH             13
# 1       Varthur  238.0  130.0            386            UPI             40
# 2   Chamarajpet  252.0   80.0            822    CREDIT CARD             45
# 3   Vijayanagar  231.0   90.0            173            UPI             41
# 4    Whitefield  133.0   40.0            140           CASH             49
#
#    driver_ratings  customer_rating  \
# 0             4.1              4.0
# 1             4.2              4.8
# 2             4.0              3.0
# 3             3.4              4.6
# 4             3.2              4.5
#
#                                       vehicle_images  ride_day  ride_month  \
# 0  https://cdn-icons-png.flaticon.com/128/9983/99...  Thursday           7
# 1  https://cdn-icons-png.flaticon.com/128/9983/99...   Tuesday           7
# 2  https://cdn-icons-png.flaticon.com/128/3202/32...   Tuesday           7
# 3  https://cdn-icons-png.flaticon.com/128/3202/32...  Saturday           7
# 4  https://cdn-icons-png.flaticon.com/128/9983/99...   Tuesday           7
#
#    ride_hour cancelled_by     booking_datetime  completed_flag
# 0         22         None  2024-07-25 22:20:00               1
# 1         19         None  2024-07-30 19:59:00               1
# 2          9         None  2024-07-02 09:02:00               1
# 3          4         None  2024-07-13 04:42:00               1
# 4          9         None  2024-07-23 09:51:00               1

# %%
#Q2. Find the average ride distance for each vehicle type

# %%
query2="""SELECT 
    vehicle_type,
    AVG(ride_distance) AS avg_ride_distance
FROM ola_rides
WHERE ride_distance > 0
GROUP BY vehicle_type;"""

# %%
df_q2 = pd.read_sql_query(query2, conn)
df_q2
# Out:
#   vehicle_type  avg_ride_distance
# 0         Auto          10.040689
# 1         Bike          24.933873
# 2        Ebike          25.146187
# 3         Mini          24.978198
# 4   Prime Plus          25.034270
# 5  Prime Sedan          25.006397
# 6    Prime Suv          24.883059

# %%
(df_q2['avg_ride_distance'] <= 0).sum()
# Out:
# np.int64(0)

# %%
df.groupby('vehicle_type')['ride_distance'].mean()
# Out:
# vehicle_type
# Auto           10.040689
# Bike           24.933873
# Ebike          25.146187
# Mini           24.978198
# Prime Plus     25.034270
# Prime Sedan    25.006397
# Prime Suv      24.883059
# Name: ride_distance, dtype: float64

# %%
#Q3. Get the total number of cancelled rides by customers

# %%
query3="""SELECT 
    COUNT(*) AS cancelled_by_customers
FROM ola_rides
WHERE booking_status = 'Cancelled'
  AND cancelled_by = 'Customer';"""

# %%
df_q3 = pd.read_sql_query(query3, conn)
df_q3
# Out:
#    cancelled_by_customers
# 0                       0

# %%
df[(df['booking_status']=='Cancelled') &
   (df['cancelled_by']=='Customer')].shape[0]
# Out:
# 0

# %%
#Q4. List the top 5 customers who booked the highest number of rides

# %%
query4="""SELECT 
    customer_id,
    COUNT(*) AS total_rides
FROM ola_rides
GROUP BY customer_id
ORDER BY total_rides DESC
LIMIT 5;"""

# %%
df_q4 = pd.read_sql_query(query4, conn)
df_q4
# Out:
#   customer_id  total_rides
# 0   CID836942            4
# 1   CID635963            4
# 2   CID329193            4
# 3   CID288207            4
# 4   CID268274            4

# %%
#Q5. Get the number of rides cancelled by drivers due to personal and car-related issues

# %%
query5="""SELECT 
    cancellation_reason_driver,
    COUNT(*) AS total_cancellations
FROM ola_rides
WHERE booking_status = 'Cancelled'
  AND cancelled_by = 'Driver'
GROUP BY cancellation_reason_driver;"""

# %%
# no rides are cancelled so i have deleted the column

# %%
#Q6. Find the maximum and minimum driver ratings for Prime Sedan bookings

# %%
query6="""SELECT 
    MAX(driver_ratings) AS max_driver_ratings,
    MIN(driver_ratings) AS min_driver_ratings
FROM ola_rides
WHERE vehicle_type = 'Prime Sedan'
  AND driver_ratings > 0;"""

# %%
pd.read_sql_query(query6, conn)
# Out:
#    max_driver_ratings  min_driver_ratings
# 0                 5.0                 3.0

# %%
#Q7. Retrieve all rides where payment was made using UPI

# %%
query7="""SELECT *
FROM ola_rides
WHERE payment_method = 'UPI';"""

# %%
df_q7 = pd.read_sql_query(query7, conn)
df_q7.shape
# Out:
# (25881, 20)

# %%
#Q8. Find the average customer rating per vehicle type

# %%
query8="""SELECT 
    vehicle_type,
    AVG(customer_rating) AS avg_customer_rating
FROM ola_rides
WHERE customer_rating > 0
GROUP BY vehicle_type;"""

# %%
pd.read_sql_query(query8, conn)
# Out:
#   vehicle_type  avg_customer_rating
# 0         Auto             3.998811
# 1         Bike             3.993376
# 2        Ebike             3.987854
# 3         Mini             3.997731
# 4   Prime Plus             4.009499
# 5  Prime Sedan             4.001589
# 6    Prime Suv             3.999378

# %%
#Q9. Calculate the total booking value of rides completed successfully

# %%
query9="""SELECT 
    SUM(booking_value) AS total_booking_value
FROM ola_rides
WHERE booking_status = 'Completed';"""

# %%
pd.read_sql_query(query9, conn)
# Out:
#    total_booking_value
# 0             35080467

# %%
df[df['booking_status']=='Completed']['booking_value'].sum()
# Out:
# np.int64(35080467)

# %%
#Q10. List all incomplete rides along with the reason

# %%
query10="""SELECT 
    booking_id,
    booking_status,
    cancellation_reason_customer,
    cancellation_reason_driver
FROM ola_rides
WHERE booking_status = 'Incomplete';"""

# %%
# there is no a single incomple ride and i have deleted te column
